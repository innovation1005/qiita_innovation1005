# %% [markdown]
# # 株価データの可視化
# ## 代表的な米国ETF(上場投資信託)

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt #描画ライブラリ
import pandas_datareader.data as web #データのダウンロードライブラリ
import numpy as np
import pandas as pd
import seaborn as sns
tsd = web.DataReader("usmv","yahoo","1980/1/1").dropna()#jpy
tsd.loc[:,'Adj Close'].plot()

# %%
tsd = web.DataReader("dia","yahoo","1980/1/1").dropna()#jpy
tsd.loc[:,'Adj Close'].plot()

# %%
tsd = web.DataReader("qqq","yahoo","1980/1/1").dropna()#jpy
tsd.loc[:,'Adj Close'].plot()

# %%
tsd = web.DataReader("^N225","yahoo","1970/1/4").dropna()#jpy
np.log(tsd.loc[:,'Adj Close']).plot()

# %%
tsd.loc['2013':,'Adj Close'].plot()

# %%
NDX=['AAL','AAPL','AMD','ALGN','ADBE','ADI','ADP','ADSK','ALXN','AMAT',
'AMGN','AMZN','ASML','ATVI','BIDU','BIIB','BMRN','BKNG','AVGO','CDNS',
'CERN','CHKP','CMCSA','COST','CSCO','CSX','CTAS','CTSH',
'CTXS','DLTR','EA','EBAY','EXPE','FAST','FB','FISV','FOX','FOXA',
'GILD','GOOG','GOOGL','HAS','HSIC','HOLX','IDXX','ILMN','INCY',
'INTC','INTU','ISRG','JBHT','JD','KHC','KLAC','LBTYB','LBTYA',
'LBTYK','LULU','LILA','LILAK','LRCX','MAR','MCHP','MELI','MNST',
'MSFT','MU','MXIM','MELI','MYL','NTAP','NFLX','NTES','NVDA','NXPI',
'ORLY','PAYX','PCAR','PYPL','PEP','QCOM','REGN','ROST','SBUX',
'SNPS','SIRI','SWKS','TMUS','TTWO','TSLA','TXN','KHC',
'ULTA','UAL','VRSN','VRSK','VRTX','WBA','WDC','WLTW','WDAY','XEL']

# %% [markdown]
# # Yahoo Finance USからダウンロードできる米国、および世界の株式指数
#
# ### 代表的なダウジョーンズ株

# %%
DJ=['AAPL','AXP','BA','CAT','CSCO','CVX','DIS','GS','HD',
    'IBM','INTC','JNJ','JPM','KO','MCD','MMM','MRK','MSFT','NKE',
    'PFE','PG','TRV','UNH','UTX','V','VZ','WBA','WMT','XOM']

# %% [markdown]
# ### 代表的な世界の株式指数

# %%
index=["^DJI","^DJT","^DJU","^BANK","^IXCO","^NDX","^NBI",
       "^NDXT","^INDS","^INSR","^OFIN","^IXTC","^TRAN","^NYY","^NYI","^NY",
       "^NYL","^XMI","^OEX","^GSPC","^HSI","^FCHI","^BVSP","^N225","^RUA","^XAX"]

# %% [markdown]
# ### 代表的なETF

# %%
ETF=['DIA','SPY','QQQ','IBB','XLV','IWM','EEM','EFA','XLP','XLY','ITB','XLU','XLF',
     'VGT','VT','FDN','IWO','IWN','IYF','XLK','XOP','USMV','BAB','GLD',
    'VNQ','SCHH','IYR','XLRE','AGG','BND','LQD','VCSH','VCIT']

# %% [markdown]
# ### 代表的なS&P500株

# %%
SP100=["AAPL","ABBV","ABT","ACN","AGN","AIG","ALL","AMGN","AMZN","AXP","BA","BAC","BIIB",
"BK","BLK","BMY","C","CAT","CHTR","CL","CMCSA","COF","COP","COST","CSCO",
"CVS","CVX","DHR","DIS","DUK","EMR","EXC","F","FB","FDX","FOX","FOXA","GD","GE",
"GILD","GM","GOOG","GOOGL","GS","HAL","HD","HON","IBM","INTC","JNJ","JPM","KHC","KMI",
"KO","LLY","LMT","LOW","MA","MCD","MDLZ","MDT","MET","MMM","MO","MRK","MS","MSFT",
"NEE","NKE","ORCL","OXY","PEP","PFE","PG","PM","PYPL","QCOM","RTN","SBUX",
"SLB","SO","SPG","T","TGT","TXN","UNH","UNP","UPS","USB","UTX","V","VZ","WBA",
"WFC","WMT","XOM"]

# %% [markdown]
# ### 代表的なクリプトカレンシー

# %%
ccurrency=["BTC-USD","XRP-USD","ETH-USD","LTC-USD","BCH-USD","BNB-USD",
       "EOS-USD","USDT-USD","LINK-USD","TRX-USD","ADA-USD",
       "XLM-USD","XMR-USD","DASH-USD","NEO-USD","IOT-USD",
       "VEN-USD","ETC-USD","XEM-USD","ZEC-USD","XRB-USD","QTUM-USD",
       "BTG-USD","BAT-USD","DOGE-USD"]

# %% [markdown]
# # 長期と中期のリスクとリターンの関係を見る
#
# ## ダウ工業株30種平均に採用されている銘柄をダウンロードしてリターンとリスクをみる
#
# ダウ工業株30種平均に採用されている銘柄をダウンロードしてリターンとリスクをみる

# %%
m=[]#それぞれの株価の年率換算平均のデータを保存
v=[]#それぞれの株価の年率換算した標準偏差を保存
for i in range(len(DJ)):
    tsd=web.DataReader(DJ[i], "yahoo",'2009/1/1')#株価データのダウンロード
    lntsd=np.log(tsd.iloc[:,5])#データの自然対数を取る
    m.append((lntsd.diff().dropna().mean()+1)**250-1)
    v.append(lntsd.diff().dropna().std()*np.sqrt(250))
    print('|{0: 03d}'.format(i+1),'{0:7s}'.format(DJ[i]),'|{0:5.2f}'.format(m[i]),
          '|{0:5.2f}'.format(v[i]),'| {0:5.2f}'.format(m[i]/v[i]),
          '|{0:10d}'.format(len(tsd)))
v_m=pd.DataFrame({'v':v,'m':m})
sns.jointplot(x='v',y='m',data=v_m,color="g")
# Out:
# | 01 AAPL    | 0.36 | 0.28 |  1.29 |      2899
# | 02 AXP     | 0.17 | 0.35 |  0.49 |      2899
# | 03 BA      | 0.16 | 0.35 |  0.46 |      2899
# | 04 CAT     | 0.13 | 0.32 |  0.41 |      2899
# | 05 CSCO    | 0.12 | 0.28 |  0.43 |      2899
# | 06 CVX     | 0.05 | 0.27 |  0.19 |      2899
# | 07 DIS     | 0.17 | 0.26 |  0.65 |      2899
# | 08 GS      | 0.09 | 0.33 |  0.28 |      2899
# | 09 HD      | 0.26 | 0.24 |  1.06 |      2899
# | 10 IBM     | 0.06 | 0.23 |  0.27 |      2899
# | 11 INTC    | 0.16 | 0.29 |  0.56 |      2899
# | 12 JNJ     | 0.11 | 0.17 |  0.65 |      2899
# | 13 JPM     | 0.13 | 0.36 |  0.35 |      2899
# | 14 KO      | 0.10 | 0.18 |  0.59 |      2899
# | 15 MCD     | 0.13 | 0.19 |  0.68 |      2899
# | 16 MMM     | 0.12 | 0.23 |  0.52 |      2899
# | 17 MRK     | 0.12 | 0.22 |  0.56 |      2899
# | 18 MSFT    | 0.26 | 0.26 |  0.98 |      2899
# | 19 NKE     | 0.23 | 0.27 |  0.88 |      2899
# | 20 PFE     | 0.10 | 0.21 |  0.46 |      2899
# | 21 PG      | 0.09 | 0.18 |  0.53 |      2899
# | 22 TRV     | 0.11 | 0.24 |  0.45 |      2899
# | 23 UNH     | 0.25 | 0.29 |  0.86 |      2899
# | 24 UTX     | 0.03 | 0.29 |  0.11 |      2836
# | 25 V       | 0.29 | 0.27 |  1.05 |      2899
# | 26 VZ      | 0.10 | 0.18 |  0.54 |      2899
# | 27 WBA     | 0.07 | 0.28 |  0.26 |      2899
# | 28 WMT     | 0.10 | 0.19 |  0.51 |      2899
# | 29 XOM     |-0.02 | 0.23 | -0.09 |      2899

# %%
m2=[]#それぞれの株価の年率換算平均のデータを保存
v2=[]#それぞれの株価の年率換算した標準偏差を保存
for i in range(len(DJ)):
    tsd=web.DataReader(DJ[i], "yahoo",'1975/1/1')#株価データのダウンロード
    lntsd=np.log(tsd.iloc[:,5])#データの自然対数を取る
    m2.append((lntsd.diff().dropna().mean()+1)**250-1)
    v2.append(lntsd.diff().dropna().std()*np.sqrt(250))
    print('|{0: 03d}'.format(i+1),'{0:7s}'.format(DJ[i]),'| {0:5.2f}'.format(m2[i]),
          '|{0:5.2f}'.format(v2[i]),'| {0:5.2f}'.format(m2[i]/v2[i]),
          '|{0:10d}'.format(len(tsd)))
v_m2=pd.DataFrame({'v2':v2,'m2':m2})
sns.jointplot(x='v2',y='m2', data=v_m2, color="g")
# Out:
# | 01 AAPL    |  0.19 | 0.46 |  0.41 |      9976
# | 02 AXP     |  0.15 | 0.34 |  0.42 |     11481
# | 03 BA      |  0.17 | 0.32 |  0.52 |     11481
# | 04 CAT     |  0.13 | 0.30 |  0.44 |     11481
# | 05 CSCO    |  0.24 | 0.41 |  0.59 |      7656
# | 06 CVX     |  0.17 | 0.27 |  0.62 |     11481
# | 07 DIS     |  0.15 | 0.30 |  0.50 |     11481
# | 08 GS      |  0.06 | 0.38 |  0.17 |      5330
# | 09 HD      |  0.28 | 0.37 |  0.74 |      9782
# | 10 IBM     |  0.11 | 0.26 |  0.42 |     11481
# | 11 INTC    |  0.15 | 0.40 |  0.37 |     10165
# | 12 JNJ     |  0.13 | 0.23 |  0.56 |     11481
# | 13 JPM     |  0.15 | 0.36 |  0.42 |     10165
# | 14 KO      |  0.20 | 0.25 |  0.80 |     11481
# | 15 MCD     |  0.24 | 0.27 |  0.91 |     11481
# | 16 MMM     |  0.14 | 0.23 |  0.60 |     11481
# | 17 MRK     |  0.13 | 0.26 |  0.49 |     11481
# | 18 MSFT    |  0.27 | 0.34 |  0.78 |      8651
# | 19 NKE     |  0.53 | 0.44 |  1.21 |      9985
# | 20 PFE     |  0.12 | 0.27 |  0.45 |     11481
# | 21 PG      |  0.20 | 0.24 |  0.84 |     11481
# | 22 TRV     |  0.09 | 0.29 |  0.31 |     11258
# | 23 UNH     |  0.24 | 0.41 |  0.59 |      9004
# | 24 UTX     |  0.20 | 0.29 |  0.70 |     11418
# | 25 V       |  0.26 | 0.31 |  0.85 |      3098
# | 26 VZ      |  0.11 | 0.24 |  0.44 |      9233
# | 27 WBA     |  0.16 | 0.29 |  0.56 |     10165
# | 28 WMT     |  0.24 | 0.28 |  0.84 |     11481
# | 29 XOM     |  0.12 | 0.23 |  0.50 |     11481

# %% [markdown]
# ## ナスダックに採用されている銘柄をダウンロードしてリターンとリスクをみる

# %%
m=[]#それぞれの株価の年率換算平均のデータを保存
v=[]#それぞれの株価の年率換算した標準偏差を保存
MKT=NDX
for i in range(len(MKT)):
    tsd=web.DataReader(MKT[i], "yahoo",'2009/1/1')#株価データのダウンロード
    lntsd=np.log(tsd.iloc[:,5])#データの自然対数を取る
    m.append((lntsd.diff().dropna().mean()+1)**250-1)
    v.append(lntsd.diff().dropna().std()*np.sqrt(250))
    if m[i]/v[i]>1:
        print('|{0: 03d}'.format(i+1),'{0:7s}'.format(MKT[i]),'|{0:5.2f}'.format(m[i]),
          '|{0:5.2f}'.format(v[i]),'| {0:5.2f}'.format(m[i]/v[i]),
          '|{0:10d}'.format(len(tsd)))
v_m=pd.DataFrame({'v':v,'m':m})
sns.jointplot(x='v',y='m',data=v_m,color="g")
# Out:
# | 02 AAPL    | 0.36 | 0.28 |  1.29 |      2899
# | 12 AMZN    | 0.42 | 0.33 |  1.27 |      2899
# | 13 ASML    | 0.34 | 0.34 |  1.00 |      2899
# | 20 CDNS    | 0.33 | 0.32 |  1.04 |      2899
# | 45 IDXX    | 0.29 | 0.28 |  1.04 |      2899
# | 58 LULU    | 0.46 | 0.45 |  1.00 |      2899
# | 79 PYPL    | 0.37 | 0.33 |  1.12 |      1262

# %%
m=[]#それぞれの株価の年率換算平均のデータを保存
v=[]#それぞれの株価の年率換算した標準偏差を保存
MKT=NDX
for i in range(len(MKT)):
    tsd=web.DataReader(MKT[i], "yahoo",'1980/1/1')#株価データのダウンロード
    lntsd=np.log(tsd.iloc[:,5])#データの自然対数を取る
    m.append((lntsd.diff().dropna().mean()+1)**250-1)
    v.append(lntsd.diff().dropna().std()*np.sqrt(250))
    if m[i]/v[i]>1:
        print('|{0: 03d}'.format(i+1),'{0:7s}'.format(MKT[i]),'|{0:5.2f}'.format(m[i]),
          '|{0:5.2f}'.format(v[i]),'| {0:5.2f}'.format(m[i]/v[i]),
          '|{0:10d}'.format(len(tsd)))
v_m=pd.DataFrame({'v':v,'m':m})
sns.jointplot(x='v',y='m',data=v_m,color="g")
# Out:
# | 79 PYPL    | 0.37 | 0.33 |  1.12 |      1262

# %% [markdown]
# ## S&P100に採用されている銘柄をダウンロードしてリターンとリスクをみる

# %%
m=[]#それぞれの株価の年率換算平均のデータを保存
v=[]#それぞれの株価の年率換算した標準偏差を保存
MKT=SP100
for i in range(len(MKT)):
    tsd=web.DataReader(MKT[i], "yahoo",'2009/1/1')#株価データのダウンロード
    lntsd=np.log(tsd.iloc[:,5])#データの自然対数を取る
    m.append((lntsd.diff().dropna().mean()+1)**250-1)
    v.append(lntsd.diff().dropna().std()*np.sqrt(250))
    if m[i]/v[i]>1:
        print('|{0: 03d}'.format(i+1),'{0:7s}'.format(MKT[i]),'|{0:5.2f}'.format(m[i]),
          '|{0:5.2f}'.format(v[i]),'| {0:5.2f}'.format(m[i]/v[i]),
          '|{0:10d}'.format(len(tsd)))
v_m=pd.DataFrame({'v':v,'m':m})
sns.jointplot(x='v',y='m',data=v_m,color="g")
# Out:
# | 01 AAPL    | 0.36 | 0.28 |  1.29 |      2899
# | 09 AMZN    | 0.42 | 0.33 |  1.27 |      2899
# | 19 CHTR    | 0.29 | 0.28 |  1.05 |      2645
# | 46 HD      | 0.26 | 0.24 |  1.06 |      2899
# | 58 MA      | 0.31 | 0.30 |  1.04 |      2899
# | 76 PYPL    | 0.37 | 0.33 |  1.12 |      1262
# | 91 V       | 0.29 | 0.27 |  1.05 |      2899

# %%
m=[]#それぞれの株価の年率換算平均のデータを保存
v=[]#それぞれの株価の年率換算した標準偏差を保存
MKT=SP100
for i in range(len(MKT)):
    tsd=web.DataReader(MKT[i], "yahoo",'1980/1/1')#株価データのダウンロード
    lntsd=np.log(tsd.iloc[:,5])#データの自然対数を取る
    m.append((lntsd.diff().dropna().mean()+1)**250-1)
    v.append(lntsd.diff().dropna().std()*np.sqrt(250))
    if m[i]/v[i]>1:
        print('|{0: 03d}'.format(i+1),'{0:7s}'.format(MKT[i]),'|{0:5.2f}'.format(m[i]),
          '|{0:5.2f}'.format(v[i]),'| {0:5.2f}'.format(m[i]/v[i]),
          '|{0:10d}'.format(len(tsd)))
v_m=pd.DataFrame({'v':v,'m':m})
sns.jointplot(x='v',y='m',data=v_m,color="g")
# Out:
# | 19 CHTR    | 0.29 | 0.28 |  1.05 |      2645
# | 20 CL      | 0.27 | 0.27 |  1.01 |     10218
# | 50 JNJ     | 0.33 | 0.28 |  1.14 |     10218
# | 58 MA      | 0.37 | 0.35 |  1.07 |      3554
# | 69 NKE     | 0.53 | 0.44 |  1.21 |      9985
# | 76 PYPL    | 0.37 | 0.33 |  1.12 |      1262

# %% [markdown]
# ## IBBに採用されている銘柄をダウンロードしてリターンとリスクをみる

# %%
BIO=['AMGN','AVGO','BIIB','BMRN','GILD','ILMN','INCY','REGN','VRTX','ALNY',
     'NKTR','EXEL','ALKS','BLUE','JAZZ','SGEN','QGEN','NBIX','SAGE','UTHR','ABBV','VXRT','INO']

# %%
m=[]#それぞれの株価の年率換算平均のデータを保存
v=[]#それぞれの株価の年率換算した標準偏差を保存
MKT=BIO
START='2009/1/1'
END='2020/12/31'
for i in range(len(MKT)):
    tsd=web.DataReader(MKT[i], "yahoo",START,END)#株価データのダウンロード
    lntsd=np.log(tsd.iloc[:,5])#データの自然対数を取る
    m.append((lntsd.diff().dropna().mean()+1)**250-1)
    v.append(lntsd.diff().dropna().std()*np.sqrt(250))
    if m[i]/v[i]>0:
        print('|{0: 03d}'.format(i+1),'{0:7s}'.format(MKT[i]),'|{0:5.2f}'.format(m[i]),
          '|{0:5.2f}'.format(v[i]),'| {0:5.2f}'.format(m[i]/v[i]),
          '|{0:10d}'.format(len(tsd)))
v_m=pd.DataFrame({'v':v,'m':m})
sns.jointplot(x='v',y='m',data=v_m,color="g")
# Out:
# | 01 AMGN    | 0.16 | 0.25 |  0.62 |      2899
# | 02 AVGO    | 0.34 | 0.36 |  0.94 |      2749
# | 03 BIIB    | 0.17 | 0.35 |  0.47 |      2899
# | 04 BMRN    | 0.19 | 0.39 |  0.48 |      2899
# | 05 GILD    | 0.11 | 0.29 |  0.39 |      2899
# | 06 ILMN    | 0.26 | 0.43 |  0.60 |      2899
# | 07 INCY    | 0.34 | 0.49 |  0.68 |      2899
# | 08 REGN    | 0.36 | 0.42 |  0.85 |      2899
# | 09 VRTX    | 0.22 | 0.44 |  0.49 |      2899
# | 10 ALNY    | 0.17 | 0.58 |  0.30 |      2899
# | 11 NKTR    | 0.14 | 0.58 |  0.24 |      2899
# | 12 EXEL    | 0.14 | 0.66 |  0.22 |      2899
# | 13 ALKS    | 0.06 | 0.48 |  0.12 |      2899
# | 14 BLUE    | 0.14 | 0.69 |  0.20 |      1776
# | 15 JAZZ    | 0.41 | 0.65 |  0.63 |      2899
# | 16 SGEN    | 0.29 | 0.44 |  0.67 |      2899
# | 17 QGEN    | 0.08 | 0.27 |  0.30 |      2899
# | 18 NBIX    | 0.38 | 0.56 |  0.67 |      2899
# | 19 SAGE    | 0.07 | 0.78 |  0.09 |      1504
# | 20 UTHR    | 0.12 | 0.35 |  0.34 |      2899
# | 21 ABBV    | 0.20 | 0.29 |  0.68 |      1892
# | 23 INO     | 0.23 | 0.97 |  0.24 |      2899

# %% [markdown]
# ## XLVに採用されている銘柄をダウンロードしてリターンとリスクをみる

# %%
HLT=['CERN','HSIC','HOLX','IDXX','ISRG','MYL','WBA','XRAY',
     'UNH','JNJ','PFE','MRK','MDT','BMY','ABT','LLY','TMO','ANTM','AGN','DHR','CI','PRGO']

# %%
m=[]#それぞれの株価の年率換算平均のデータを保存
v=[]#それぞれの株価の年率換算した標準偏差を保存
MKT=HLT
START='2009/1/1'
END='2020/12/31'
for i in range(len(MKT)):
    tsd=web.DataReader(MKT[i], "yahoo",START,END)#株価データのダウンロード
    lntsd=np.log(tsd.iloc[:,5])#データの自然対数を取る
    m.append((lntsd.diff().dropna().mean()+1)**250-1)
    v.append(lntsd.diff().dropna().std()*np.sqrt(250))
    if m[i]/v[i]>0:
        print('|{0: 03d}'.format(i+1),'{0:7s}'.format(MKT[i]),'|{0:5.2f}'.format(m[i]),
          '|{0:5.2f}'.format(v[i]),'| {0:5.2f}'.format(m[i]/v[i]),
          '|{0:10d}'.format(len(tsd)))
v_m=pd.DataFrame({'v':v,'m':m})
sns.jointplot(x='v',y='m',data=v_m,color="g")
# Out:
# | 01 CERN    | 0.19 | 0.27 |  0.69 |      2899
# | 02 HSIC    | 0.13 | 0.24 |  0.53 |      2899
# | 03 HOLX    | 0.14 | 0.31 |  0.43 |      2899
# | 04 IDXX    | 0.29 | 0.28 |  1.04 |      2899
# | 05 ISRG    | 0.25 | 0.34 |  0.76 |      2899
# | 06 MYL     | 0.04 | 0.36 |  0.12 |      2899
# | 07 WBA     | 0.07 | 0.28 |  0.26 |      2899
# | 08 XRAY    | 0.04 | 0.26 |  0.16 |      2899
# | 09 UNH     | 0.25 | 0.29 |  0.86 |      2899
# | 10 JNJ     | 0.11 | 0.17 |  0.65 |      2899
# | 11 PFE     | 0.10 | 0.21 |  0.46 |      2899
# | 12 MRK     | 0.12 | 0.22 |  0.56 |      2899
# | 13 MDT     | 0.12 | 0.23 |  0.52 |      2899
# | 14 BMY     | 0.12 | 0.24 |  0.50 |      2899
# | 15 ABT     | 0.16 | 0.22 |  0.74 |      2899
# | 16 LLY     | 0.17 | 0.23 |  0.77 |      2899
# | 17 TMO     | 0.24 | 0.25 |  0.95 |      2899
# | 18 ANTM    | 0.19 | 0.30 |  0.61 |      2899
# | 19 AGN     | 0.20 | 0.28 |  0.72 |      2858
# | 20 DHR     | 0.25 | 0.25 |  0.99 |      2899
# | 21 CI      | 0.23 | 0.33 |  0.69 |      2899
# | 22 PRGO    | 0.05 | 0.35 |  0.16 |      2899
